# %%
import pandas as pd

aqi = pd.read_csv("Ahmedabad_AQI_Daily.csv")
print(aqi.head())
print(aqi.describe())
# Out:
#          Date   NO2  PM10  PM2_5  PM2_5_Lag1  PM2_5_Lag7  PM10_Lag1  \
# 0  2025-02-24  10.1  39.8   73.2        61.8   68.628571       39.8
# 1  2025-02-25  10.1  39.8   85.5        73.2   75.571429       39.8
# 2  2025-02-26  10.1  39.8   84.1        85.5   79.485714       39.8
# 3  2025-02-27  10.1  39.8  115.0        84.1   76.628571       39.8
# 4  2025-02-28  10.1  39.8   94.1       115.0   78.185714       39.8
#
#    PM10_Lag7  NO2_Lag1  NO2_Lag7
# 0       39.8      10.1      10.1
# 1       39.8      10.1      10.1
# 2       39.8      10.1      10.1
# 3       39.8      10.1      10.1
# 4       39.8      10.1      10.1
#          NO2          PM10       PM2_5  PM2_5_Lag1  PM2_5_Lag7     PM10_Lag1  \
# count  343.0  3.430000e+02  343.000000  343.000000  343.000000  3.430000e+02
# mean    10.1  3.980000e+01   37.162915   37.253586   37.385573  3.980000e+01
# std      0.0  1.423162e-14   23.147272   23.182765   19.921874  1.423162e-14
# ...

# %%
print(df["parameter"].unique())
print(df.groupby("parameter")["value"].describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(df["parameter"].unique())
#       2 print(df.groupby("parameter")["value"].describe())
#
# NameError: name 'df' is not defined
